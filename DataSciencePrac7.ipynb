# %% [markdown]
# <a href="https://colab.research.google.com/github/VipulShinde21/DVProject/blob/main/DataSciencePrac7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Loading data
import matplotlib.pyplot as plt
import pandas as pd
# df=pd.read_csv('/content/IPL Matches 2008-2020.csv')
df1=pd.read_excel('/content/IPL Matches 2008-2020(Excel).xlsx')
df1
# Out:
#           id        city       date player_of_match  \
# 0     335982   Bangalore 2008-04-18     BB McCullum
# 1     335983  Chandigarh 2008-04-19      MEK Hussey
# 2     335984       Delhi 2008-04-19     MF Maharoof
# 3     335985      Mumbai 2008-04-20      MV Boucher
# 4     335986     Kolkata 2008-04-20       DJ Hussey
# ..       ...         ...        ...             ...
# 811  1216547       Dubai 2020-09-28  AB de Villiers
# 812  1237177       Dubai 2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi 2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi 2020-11-08      MP Stoinis
# 815  1237181       Dubai 2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
import matplotlib.image as mpimg
img=mpimg.imread('/content/Ipl image.jpg')
plt.imshow(img)

# %%
# Dataframe
import pandas as pd
df=pd.DataFrame({"Marks":[85,84,95,85,62],"Roll no":[6213,6213,6181,6108,6183],"Name":['Vipul','Vipul','pradeep','atharv','vivek'],"Class":['A','A','B','B','B']})
print(df)
# Out:
#    Marks  Roll no     Name Class
# 0     85     6213    Vipul     A
# 1     84     6213    Vipul     A
# 2     95     6181  pradeep     B
# 3     85     6108   atharv     B
# 4     62     6183    vivek     B

# %%
df.sum()
# Out:
# Marks                               411
# Roll no                           30898
# Name       VipulVipulpradeepatharvvivek
# Class                             AABBB
# dtype: object

# %%
df.isnull()
# Out:
#    Marks  Roll no   Name  Class
# 0  False    False  False  False
# 1  False    False  False  False
# 2  False    False  False  False
# 3  False    False  False  False
# 4  False    False  False  False

# %%
df.describe()
# Out:
#            Marks      Roll no
# count   5.000000     5.000000
# mean   82.400000  6179.600000
# std    12.198361    42.927846
# min    62.000000  6108.000000
# 25%    85.000000  6181.000000
# 50%    85.000000  6183.000000
# 75%    85.000000  6213.000000
# max    95.000000  6213.000000

# %%
df.describe(include=object)
# Out:
#          Name
# count       5
# unique      4
# top     Vipul
# freq        2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Marks    5 non-null      int64
#  1   Roll no  5 non-null      int64
#  2   Name     5 non-null      object
# dtypes: int64(2), object(1)
# memory usage: 248.0+ bytes

# %%
df.nunique()
# Out:
# Marks      4
# Roll no    4
# Name       4
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df["Name"]
# Out:
# 0      Vipul
# 1      Vipul
# 2    pradeep
# 3     atharv
# 4      vivek
# Name: Name, dtype: object

# %%
df.Name
# Out:
# 0      Vipul
# 1      Vipul
# 2    pradeep
# 3     atharv
# 4      vivek
# Name: Name, dtype: object

# %%
df["Name"].value_counts()
# Out:
# Vipul      2
# pradeep    1
# atharv     1
# vivek      1
# Name: Name, dtype: int64

# %%
df.nunique()
# Out:
# Marks      4
# Roll no    4
# Name       4
# Class      2
# dtype: int64

# %%
df.value_counts()
# Out:
# Marks  Roll no  Name     Class
# 62     6183     vivek    B        1
# 84     6213     Vipul    A        1
# 85     6108     atharv   B        1
#        6213     Vipul    A        1
# 95     6181     pradeep  B        1
# dtype: int64

# %%
df["Class"].value_counts()
# Out:
# B    3
# A    2
# Name: Class, dtype: int64

# %%
df["Marks"].mean() #Average
# Out:
# 82.2

# %%
df["Marks"].var() #Variance of the data [if it is lower than mean its good]
# Out:
# 147.7

# %%
df
# Out:
#    Marks  Roll no     Name Class
# 0     85     6213    Vipul     A
# 1     84     6213    Vipul     A
# 2     95     6181  pradeep     B
# 3     85     6108   atharv     B
# 4     62     6183    vivek     B

# %%
corr = df.corr()
# Out:
# <ipython-input-72-45893e33df67>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()

# %%
import seaborn as sns

# %%
sns.heatmap(corr,annot=True,fmt=".2f",cmap="plasma") # correlation and give annotation and fmt(to manage digits aftsr .) and cmap for color
# Out:
# <Axes: >
